# %%
import os
from collections import Counter

# %%
def read_file_lines(filepath):
    """Считывает строки из файла и возвращает их в виде словаря с количеством вхождений."""
    if not os.path.exists(filepath):
        return None
    with open(filepath, 'r', encoding='utf-8') as file:
        return Counter(line.strip() for line in file)

# %%
def compare_files(directory):
    total = 0
    ok = 0
    """Рекурсивно обходит файлы в указанной папке и сравнивает пары файлов .res и .res_land."""
    for root, _, files in os.walk(directory):
        for filename in files:
            if filename.endswith(".res") and not filename.endswith(".res_land"):
                base_name = filename[:-4]  # Убираем расширение .res
                res_file = os.path.join(root, filename)
                res_land_file = os.path.join(root, f"{base_name}.res_land")
                
                lines_res = read_file_lines(res_file)
                lines_res_land = read_file_lines(res_land_file)
                
                total+=1
                
                if lines_res is None or lines_res_land is None:
                    print(f"Файл отсутствует: {res_file if lines_res is None else res_land_file}")
                    continue
                
                if lines_res == lines_res_land:
                    ok += 1
                    #print(f"✔ Файлы {filename} и {base_name}.res_land совпадают")
                else:
                    missing_in_res = {line: count for line, count in lines_res_land.items() if count > lines_res.get(line, 0)}
                    missing_in_res_land = {line: count for line, count in lines_res.items() if count > lines_res_land.get(line, 0)}
                    print(f"❌ Разница в файлах {root} {filename} и {base_name}.res_land:")
                    if missing_in_res:
                        print("  В .res_land есть, а в .res не хватает:", missing_in_res)
                    if missing_in_res_land:
                        print("  В .res есть, а в .res_land не хватает:", missing_in_res_land)
    print(f"OK: {ok} ({ok/total*100}%), BAD: {total-ok}, TOTAL: {total}")

# %%
directory_path = "e:\\phd\\ts_res"
compare_files(directory_path)
# Out:
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo codegen.res и codegen.res_land:
#   В .res_land есть, а в .res не хватает: {'content': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\payment PaymentChart.res и PaymentChart.res_land:
#   В .res есть, а в .res_land не хватает: {'getChartConfig': 1, 'getTableConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\resident ResidentChart.res и ResidentChart.res_land:
#   В .res есть, а в .res_land не хватает: {'getChartConfig': 1, 'getTableConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\ticket dataMappers.res и dataMappers.res_land:
#   В .res есть, а в .res_land не хватает: {'chart': 4, 'table': 4}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'filter': 2, 'viewMode': 4, 'ticketType': 2, 'mainGroup': 2, 'id': 4, 'AND': 1, 'groupBy': 1, 'legend': 2, 'animationEnabled': 2, 'axisData': 2, 'tooltip': 2, 'series': 2, 'chartOptions': 2, 'animation': 1, 'color': 2, 'data': 2, 'option': 1, 'opts': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'range': 5, 'filter': 5}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\components\BillingPageContent ContextProvider.res и ContextProvider.res_land:
#   В .res есть, а в .res_land не хватает: {'refetchBilling': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\hooks useReceiptTableColumns.res и useReceiptTableColumns.res_land:
#   В .res есть, а в .res_land не хватает: {'title': 10, 'filterIcon': 5, 'placeholder': 4}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components BaseChart.res и BaseChart.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components FocusContainer.res и FocusContainer.res_land:
#   В .res есть, а в .res_land не хватает: {'margin': 1, 'color': 1, 'padding': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\containers\BaseLayout\components styles.res и styles.res_land:
#   В .res есть, а в .res_land не хватает: {'isSmall': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\PostMessageProvider validators.res и validators.res_land:
#   В .res есть, а в .res_land не хватает: {'CondoWebAppGetActiveProgressBars': 1, 'CondoWebAppGetLaunchParams': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\tasks TaskLauncher.res и TaskLauncher.res_land:
#   В .res есть, а в .res_land не хватает: {'record': 1, 'onComplete': 1, 'onCancel': 1, 'onError': 1, 'loading': 1, 'handleRunTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers AmplitudeInstance.res и AmplitudeInstance.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'init': 1, 'logInstanceEvent': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers TrackerInstance.res и TrackerInstance.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'logEvent': 1, 'eventName': 1, 'eventProperties': 1, 'denyDuplicates': 1, 'isNeedToSendEvent': 1, '_getLogEventPermissionFromConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers TrackerInstance.spec.res и TrackerInstance.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'TRACKER_DOMAIN': 1, 'constructor': 1, 'init': 1, 'logInstanceEvent': 1, 'eventName': 7}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useCheckboxSearch.res и useCheckboxSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'newParameters': 1, 'value': 1, 'handleChange': 1, 'handleFilterChanges': 1, 'handleResetWithoutUpdateQuery': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useDateRangeSearch.res и useDateRangeSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'filterKey': 1, 'newParameters': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useDownloadFileFromServer.res и useDownloadFileFromServer.res_land:
#   В .res есть, а в .res_land не хватает: {'downloadFile': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useImporter.res и useImporter.res_land:
#   В .res есть, а в .res_land не хватает: {'value': 1, 'title': 3, 'message': 7, 'columns': 1, 'rowNormalizer': 1, 'rowValidator': 1, 'objectCreator': 1, 'setTotalRows': 1, 'setSuccessRows': 1, 'handleRowError': 1, 'onFinish': 1, 'onError': 1, 'mutationErrorsToMessages': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks usePreviousQueryParams.res и usePreviousQueryParams.res_land:
#   В .res есть, а в .res_land не хватает: {'set': 1, 'get': 1, 'getAll': 1, 'getStorageKey': 1, 'getPageKey': 1, 'newParameters': 1, 'paramNamesForPageChange': 3, 'employeeSpecificKey': 3, 'trackedParamNames': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useQueryMappers.res и useQueryMappers.res_land:
#   В .res есть, а в .res_land не хватает: {'combineType': 1, 'AND': 1, 'filtersToWhere': 1, 'sortersToSortBy': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useSearch.res и useSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'search': 1, 'newParameters': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useValidations.res и useValidations.res_land:
#   В .res есть, а в .res_land не хватает: {'message': 5, 'validator': 8, 'min': 1, 'max': 1, 'changeMessage': 1, 'requiredValidator': 1, 'phoneValidator': 1, 'emailValidator': 1, 'trimValidator': 1, 'specCharValidator': 1, 'lessThanValidator': 1, 'greaterThanValidator': 1, 'minLengthValidator': 1, 'maxLengthValidator': 1, 'numberValidator': 1, 'tinValidator': 1, 'multipleEmailsValidator': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useWindowSize.res и useWindowSize.res_land:
#   В .res есть, а в .res_land не хватает: {'width': 1, 'height': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils addressApi.res и addressApi.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'getSuggestions': 1, 'getRawAddress': 1, 'cacheRawAddress': 1, 'setAddressSuggestionsConfig': 1, 'setSessionConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils date.utils.res и date.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'deadline': 2, 'isDefault': 1, 'startWithDate': 2, 'show': 1, 'TimeLeftMessage': 1, 'OverdueMessage': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils excel.utils.res и excel.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'flat': 1, 'floor': 1, 'section': 1, 'address': 1, 'name': 1, 'email': 1, 'phone': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'flatPart': 1, 'streetPart': 1, 'areaPart': 1, 'settlementPart': 1, 'regionPart': 1, 'cityPart': 1, 'renderPostfix': 1, 'shallow': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils importer.res и importer.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'import': 1, 'break': 1, 'onError': 1, 'onFinish': 1, 'onRowProcessed': 1, 'onRowFailed': 1, 'onProgressUpdate': 1, 'isColumnsValid': 1, 'parseAndValidateRow': 1, 'updateProgress': 1, 'createRecord': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils importer.spec.res и importer.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'message': 7}
#   В .res есть, а в .res_land не хватает: {'row': 2, 'value': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils pdf.res и pdf.res_land:
#   В .res есть, а в .res_land не хватает: {'imageData': 1, 'width': 1, 'height': 1, 'windowWidth': 1, 'windowHeight': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils tables.utils.res и tables.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'propertyName': 1, 'current': 1, 'columnKey': 1, 'filters': 1, 'sorters': 1, 'offset': 1, 'tab': 1, 'width': 1, 'filterIcon': 1, 'filterDropdown': 1, 'responsive': 1, 'render': 1, 'disabled': 1, 'placeholder': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils tables.utils.spec.res и tables.utils.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'propertyName': 6, 'target': 4, 'sort': 3, 'render': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\next apollo.res и apollo.res_land:
#   В .res есть, а в .res_land не хватает: {'cacheOptions': 1, 'uri': 1, 'cacheConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\hooks useContactExportTaskUIInterface.res и useContactExportTaskUIInterface.res_land:
#   В .res есть, а в .res_land не хватает: {'ContactExportTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'name_contains_i': 2, 'phone_contains_i': 2, 'email_contains_i': 2, 'address_contains_i': 2, 'OR': 1, 'AND': 1, 'columnKey': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'name_contains_i': 2, 'phone_contains_i': 2, 'email_contains_i': 2, 'address_contains_i': 2, 'key': 5}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils\clientSchema ContactRole.res и ContactRole.res_land:
#   В .res есть, а в .res_land не хватает: {'value': 1, 'label': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\components\MarketplacePageContent ContextProvider.res и ContextProvider.res_land:
#   В .res есть, а в .res_land не хватает: {'refetchAcquiringContext': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\components MetersDataImporterTypes.res и MetersDataImporterTypes.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'getMessages': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\hooks useMeterReadingExportTaskUIInterface.res и useMeterReadingExportTaskUIInterface.res_land:
#   В .res есть, а в .res_land не хватает: {'MeterReadingExportTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\hooks useMeterValidations.res и useMeterValidations.res_land:
#   В .res есть, а в .res_land не хватает: {'validator': 5, 'meterWithSameAccountNumberInOtherUnitValidation': 1, 'meterWithSameNumberValidator': 1, 'earlierThanFirstVerificationDateValidator': 1, 'earlierThanInstallationValidator': 1, 'meterResourceOwnerValidation': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'value': 3, 'normalized': 4, 'isValid': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'COLD_WATER_METER_RESOURCE_ID': 1, 'HOT_WATER_METER_RESOURCE_ID': 1, 'GAS_SUPPLY_METER_RESOURCE_ID': 1, 'ELECTRICITY_METER_RESOURCE_ID': 1, 'HEAT_SUPPLY_METER_RESOURCE_ID': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema search.res и search.res_land:
#   В .res есть, а в .res_land не хватает: {'name_contains_i': 1, 'text': 1, 'value': 1, 'name': 1, 'id': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useNewsItemRecipientsExportTaskUIInterface.res и useNewsItemRecipientsExportTaskUIInterface.res_land:
#   В .res есть, а в .res_land не хватает: {'NewsItemRecipientsExportTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useNewsItemsAccess.res и useNewsItemsAccess.res_land:
#   В .res есть, а в .res_land не хватает: {'canRead': 1, 'canManage': 1, 'isLoading': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useTableFilters.res и useTableFilters.res_land:
#   В .res есть, а в .res_land не хватает: {'label': 2, 'value': 2, 'options': 1, 'placeholder': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\onboarding\utils\clientSchema constants.res и constants.res_land:
#   В .res есть, а в .res_land не хватает: {'CREATE_PROPERTY_MAP_STEP_TYPE': 1, 'VIEW_RESIDENT_APP_GUIDE_STEP_TYPE': 1, 'LinkWrapper': 8, 'AfterIcon': 8, 'href': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\organization\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'name_contains_i': 2, 'phone_contains_i': 2, 'email_contains_i': 2, 'position_contains_i': 2, 'role': 1, 'OR': 1, 'AND': 1, 'columnKey': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\organization\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 2, 'phone': 2, 'email': 2, 'role': 2, 'search': 2, 'position': 1, 'offset': 1, 'name_contains_i': 2, 'phone_contains_i': 2, 'email_contains_i': 2, 'position_contains_i': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\organization\utils roles.utils.res и roles.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'id': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\organization\utils\clientSchema OrganizationEmployeeRole.res и OrganizationEmployeeRole.res_land:
#   В .res есть, а в .res_land не хватает: {'value': 1, 'label': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\components\panels\Builder MapConstructor.res и MapConstructor.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 3, 'sectionIds': 1, 'floorIds': 1, 'unitIds': 1, 'getMap': 1, 'validateSchema': 1, 'validate': 1, 'validateUniqueIds': 1, 'validateUniqueUnits': 1, 'getSectionFloorNames': 1, 'setAutoincrement': 1, 'repairMapStructure': 1, 'getSectionMaxFloor': 1, 'maxFloor': 1, 'minFloor': 1, 'possibleFloors': 1, 'possibleChosenFloors': 1, 'possibleChosenParkingFloors': 1, 'isEmptySections': 1, 'isEmptyParking': 1, 'isEmpty': 1, 'setVisibleSections': 1, 'isSectionVisible': 1, 'setVisibleParkingSections': 1, 'isParkingSectionVisible': 1, 'sections': 1, 'parking': 1, 'lastSectionIndex': 1, 'lastParkingIndex': 1, 'getUnitInfo': 1, 'getParkingUnitInfo': 1, 'getSectionOptions': 1, 'getParkingSectionOptions': 1, 'getSectionFloorOptions': 1, 'getParkingSectionFloorOptions': 1, 'getUnitTypeOptions': 1, 'getUnitIndex': 1, 'getParkingUnitIndex': 1, 'restoreViewMode': 1, 'previewParkingUnitId': 1, 'previewUnitId': 1, 'previewSectionFloor': 1, 'previewParkingId': 1, 'previewSectionId': 1, 'duplicatedUnits': 1, 'nextUnitNumber': 1, 'nextParkingUnitNumber': 1, 'nextSectionName': 1, 'nextParkingName': 1, 'editMode': 2, 'hasPreviewComponents': 1, 'validateInputUnitLabel': 1, 'validateInputParkingUnitLabel': 1, 'setSelectedSection': 1, 'setSelectedParking': 1, 'getSelectedSection': 1, 'getSelectedParking': 1, 'isParkingSelected': 1, 'isSectionSelected': 1, 'setSelectedParkingUnit': 1, 'getSelectedParkingUnit': 1, 'isParkingUnitSelected': 1, 'removePreviewParkingUnit': 1, 'setSelectedUnit': 1, 'getSelectedUnit': 1, 'isUnitSelected': 1, 'removePreviewSection': 1, 'removePreviewUnit': 1, 'removePreviewSectionFloor': 1, 'addPreviewSection': 1, 'addSection': 1, 'addPreviewSectionFloor': 1, 'addSectionFloor': 1, 'addPreviewCopySection': 1, 'addCopySection': 1, 'updateSection': 1, 'removeSection': 1, 'updateParking': 1, 'removeParking': 1, 'removePreviewParking': 1, 'addPreviewParking': 1, 'addParking': 1, 'addPreviewCopyParking': 1, 'addCopyParking': 1, 'addPreviewUnit': 1, 'addPreviewParkingUnit': 1, 'addParkingUnit': 1, 'addUnit': 1, 'removeUnit': 1, 'removeParkingUnit': 1, 'updateParkingUnit': 1, 'updateUnit': 1, 'updateUnitNumbers': 1, 'updateParkingUnitNumbers': 1, 'generateSection': 1, 'generateSingleParking': 1, 'generateFloor': 1, 'insertFloor': 1, 'getNextParkingUnit': 1, 'getNextUnit': 1, 'removeFloor': 1, 'removeParkingFloor': 1, 'notifyUpdater': 1, 'updateSectionNumbers': 1, 'updateParkingNumbers': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\components\panels\Builder MapConstructor.spec.res и MapConstructor.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 2, 'index': 5}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\hooks usePropertyValidations.res и usePropertyValidations.res_land:
#   В .res есть, а в .res_land не хватает: {'validator': 2, 'addressValidator': 1, 'yearOfConstructionValidator': 1, 'organizationId': 1, 'addressValidatorError': 1, 'address': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\hooks useTableFilters.res и useTableFilters.res_land:
#   В .res есть, а в .res_land не хватает: {'placeholder': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'address_contains_i': 2, 'OR': 1, 'AND': 1, 'value': 1, 'data': 1, 'postfix': 1, 'extraProps': 1, 'text': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'address': 2, 'search': 2, 'offset': 1, 'address_contains_i': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\property\utils tables.utils.res и tables.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'field.UnitType.prefix.flat': 1, 'field.UnitType.prefix.parking': 1, 'field.UnitType.prefix.apartment': 1, 'field.UnitType.prefix.warehouse': 1, 'field.UnitType.prefix.commercial': 1, 'unitName_i': 1, 'unitType': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useBooleanAttributesSearch.res и useBooleanAttributesSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'attributes': 1, 'newParameters': 1, 'attributeName': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useImporterFunctions.res и useImporterFunctions.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 8, 'row': 1, 'addons': 1, 'columnName': 1, 'format': 1, 'clientName': 1, 'clientPhone': 1, 'isResidentTicket': 1, 'id': 2, 'unitName': 1, 'unitType': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useIncidentExportTaskUIInterface.res и useIncidentExportTaskUIInterface.res_land:
#   В .res есть, а в .res_land не хватает: {'IncidentExportTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useIncidentTableFilters.res и useIncidentTableFilters.res_land:
#   В .res есть, а в .res_land не хватает: {'label': 2, 'value': 2, 'placeholder': 3, 'options': 1, 'disabledDate': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useStatusTransitions.res и useStatusTransitions.res_land:
#   В .res есть, а в .res_land не хватает: {'loading': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\hooks useTicketExportTaskUIInterface.res и useTicketExportTaskUIInterface.res_land:
#   В .res есть, а в .res_land не хватает: {'TicketExportTask': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\utils helpers.res и helpers.res_land:
#   В .res есть, а в .res_land не хватает: {'deferredUntil': 1, 'clientName_contains_i': 2, 'details_contains_i': 2, 'executor': 2, 'assignee': 2, 'property': 2, 'status': 2, 'OR': 1, 'AND': 1, 'columnKey': 1, 'validPageSize': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\utils helpers.spec.res и helpers.spec.res_land:
#   В .res есть, а в .res_land не хватает: {'status': 2, 'assignee': 2, 'clientName': 2, 'details': 2, 'executor': 2, 'number': 2, 'property': 2, 'search': 2, 'isEmergency': 1, 'offset': 1, 'pagesize': 1, 'clientName_contains_i': 2, 'details_contains_i': 2, 'locale': 4}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\utils tables.utils.res и tables.utils.res_land:
#   В .res есть, а в .res_land не хватает: {'': 1, 'status': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\utils\clientSchema classifierSearch.res и classifierSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 2, 'init': 2, 'rulesToOptions': 2, 'findRules': 2, 'findRulesBySelectedClassifiers': 1, 'search': 2, 'clear': 2, 'place': 1, 'category': 1, 'problem': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\ticket\utils\clientSchema incidentClassifierSearch.res и incidentClassifierSearch.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'init': 1, 'rulesToOptions': 1, 'search': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src news.test.res и news.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'appHealthcheck': 1, 'browser': 1, 'http_req_failed': 1, 'browser_http_req_duration': 1, 'http_req_duration': 1, 'browser_web_vital_fcp': 1, 'browser_web_vital_lcp': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 2}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src payment.test.res и payment.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'registerBillingReceipts': 1, 'http_req_failed': 1, 'http_req_duration': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 1, 'min': 1, 'max': 1, 'month': 1, 'year': 1, 'raw': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src registerBillingReceipt.test.res и registerBillingReceipt.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'registerBillingReceipt': 1, 'http_req_failed': 1, 'http_req_duration': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 1, 'min': 1, 'max': 1, 'month': 1, 'year': 1, 'raw': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src registerBillingReceiptFile.test.res и registerBillingReceiptFile.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'registerBillingReceiptFile': 1, 'http_req_failed': 1, 'http_req_duration': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 1, 'min': 1, 'max': 1, 'month': 1, 'year': 1, 'raw': 1, 'bankAccount': 1, 'address': 2, 'receipts': 2, 'receipt creation status is 200': 1, 'receipts is created': 1, 'unitName': 1, 'accountNumberPrefix': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src registerMetersReadings.test.res и registerMetersReadings.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'registerMetersReadings': 1, 'http_req_failed': 1, 'http_req_duration': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 1, 'unitType': 1, 'id': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src syncTourStep.test.res и syncTourStep.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'syncTourSteps': 1, 'http_req_failed': 1, 'http_req_duration': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src ticket.test.res и ticket.test.res_land:
#   В .res_land есть, а в .res не хватает: {'testid': 1, 'serverUrl': 1, 'queryTicketEntities': 1, 'appHealthcheck': 1, 'createTickets': 1, 'browser': 1, 'http_req_failed': 1, 'browser_http_req_duration': 1, 'http_req_duration': 1, 'browser_web_vital_fcp': 1, 'browser_web_vital_lcp': 1}
#   В .res есть, а в .res_land не хватает: {'duration': 4}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\k6\src utils.res и utils.res_land:
#   В .res есть, а в .res_land не хватает: {'token': 3, 'where': 1, 'id': 6, 'index': 1, 'address': 2, 'map': 1, 'name': 1, 'currencyCode': 1, 'unitName': 1, 'unitType': 1, 'accountNumber': 1, 'base64EncodedPDF': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\dev-portal-web\domains\common\constants antd.res и antd.res_land:
#   В .res_land есть, а в .res не хватает: {'colorPrimary': 1, 'colorPrimaryBg': 1, 'colorPrimaryBgHover': 1, 'colorBgContainer': 1, 'colorFillTertiary': 1, 'colorError': 1, 'fontFamily': 1, 'Menu': 1, 'Divider': 1, 'Table': 1, 'Pagination': 1, 'Collapse': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\dev-portal-web\pages\api graphql.res и graphql.res_land:
#   В .res_land есть, а в .res не хватает: {'bodyParser': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\apollo\src\utils cache.res и cache.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\apollo\src\utils client.res и client.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, '_getCacheConfig': 1, 'initializeApollo': 1, 'generateUseApolloHook': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\apollo\src\utils lists.res и lists.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, '_readPage': 1, '_networkOnlyRead': 1, 'getReadFunction': 1, 'mergeLists': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\bridge\src\types errors.res и errors.res_land:
#   В .res есть, а в .res_land не хватает: {'ACCESS_DENIED_ERROR': 1, 'UNKNOWN_ERROR': 1, 'UNKNOWN_METHOD_ERROR': 1, 'INVALID_PARAMETERS_ERROR': 1, 'HANDLER_ERROR': 1, 'TIMEOUT_REACHED_ERROR': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\icons\bin\import index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'componentName': 2, 'jsx': 1, 'apiToken': 1, 'fileId': 1, 'pageName': 1, 'componentPrefix': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\icons\bin\import svgr.config.res и svgr.config.res_land:
#   В .res есть, а в .res_land не хватает: {'template': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\icons\bin\import template.res и template.res_land:
#   В .res есть, а в .res_land не хватает: {'ResolverTest_class_1_func_1': 1, 'ResolverTest_class_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\miniapp-utils\src\helpers cookies.res и cookies.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'getContext': 1, 'generateUseSSRCookiesExtractorHook': 1, 'generateUseSSRCookiesHook': 1, 'extractSSRCookies': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\next _useEmitterMutation.res и _useEmitterMutation.res_land:
#   В .res есть, а в .res_land не хватает: {'on': 1, 'once': 1, 'off': 1, 'emit': 1, 'addListener': 1, 'removeListener': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\ui\.storybook main.res и main.res_land:
#   В .res есть, а в .res_land не хватает: {'webpackFinal': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\ui\.storybook manager.res и manager.res_land:
#   В .res есть, а в .res_land не хватает: {'theme': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\ui\src\components\Tour index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'TourStep': 1, 'Provider': 1, 'useTourContext': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\ui\src\components\Typography index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'Text': 1, 'Title': 1, 'Link': 1, 'Paragraph': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\packages\ui\src\components\_utils responsiveObserve.res и responsiveObserve.res_land:
#   В .res есть, а в .res_land не хватает: {'MOBILE_SMALL': 1, 'MOBILE_LARGE': 1, 'TABLET_SMALL': 1, 'TABLET_LARGE': 1, 'DESKTOP_SMALL': 1, 'DESKTOP_LARGE': 1, 'dispatch': 1, 'subscribe': 1, 'unsubscribe': 1, 'unregister': 1, 'register': 1}
# ❌ Разница в файлах e:\phd\ts_res\daily-facts-api\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'url': 1}
# ❌ Разница в файлах e:\phd\ts_res\daily-facts-api\src server.res и server.res_land:
#   В .res есть, а в .res_land не хватает: {'filename': 1, 'date': 1, 'schema': 1, 'context': 1}
# ❌ Разница в файлах e:\phd\ts_res\daily-facts-api\src\resolvers facts.res и facts.res_land:
#   В .res есть, а в .res_land не хватает: {'facts': 1}
# ❌ Разница в файлах e:\phd\ts_res\daily-facts-api\src\services facts.res и facts.res_land:
#   В .res есть, а в .res_land не хватает: {'all': 1, 'findByDate': 1, 'findByMonthAndDay': 1, 'upsertOne': 1, 'removeMany': 1, 'removeOne': 1, 'findOne': 1, 'insert': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.keyvaluecache\src ErrorsAreMissesCache.res и ErrorsAreMissesCache.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'get': 1, 'set': 1, 'delete': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.keyvaluecache\src InMemoryLRUCache.res и InMemoryLRUCache.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'sizeCalculation': 1, 'set': 1, 'get': 1, 'delete': 1, 'clear': 1, 'keys': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.keyvaluecache\src PrefixingKeyValueCache.res и PrefixingKeyValueCache.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'get': 1, 'set': 1, 'delete': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.keyvaluecache\src\__tests__ ErrorsAreMissesCache.test.res и ErrorsAreMissesCache.test.res_land:
#   В .res есть, а в .res_land не хватает: {'get': 1, 'set': 1, 'delete': 1, 'debug': 1, 'info': 1, 'warn': 1, 'error': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.keyvaluecache\src\__tests__ keyValueCache.test.res и keyValueCache.test.res_land:
#   В .res есть, а в .res_land не хватает: {'get': 3, 'set': 3, 'delete': 3}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.logger\src\__tests__ index.test.res и index.test.res_land:
#   В .res есть, а в .res_land не хватает: {'level': 3, 'message': 3, 'configure': 1, 'msg': 1, 'constructor': 1, 'log': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.printwithreducedwhitespace\src\__tests__ printWithReducedWhitespace.test.res и printWithReducedWhitespace.test.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 1, 'input': 1, 'output': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.usagereporting\dist calculateReferencedFieldsByType.d.res и calculateReferencedFieldsByType.d.res_land:
#   В .res есть, а в .res_land не хватает: {'document': 1, 'schema': 1, 'resolvedOperationName': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@apollo\utils.usagereporting\src\__tests__ signature.test.res и signature.test.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 1, 'operationName': 1, 'input': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\node_modules\@graphql-tools\schema\typings addResolversToSchema.d.res и addResolversToSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'resolvers': 1, 'defaultFieldResolver': 1, 'resolverValidationOptions': 1, 'inheritResolversFromInterfaces': 1, 'updateResolversInPlace': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\node_modules\@graphql-tools\schema\typings makeExecutableSchema.d.res и makeExecutableSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'resolverValidationOptions': 1, 'inheritResolversFromInterfaces': 1, 'updateResolversInPlace': 1, 'schemaExtensions': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\node_modules\@graphql-tools\utils\typings build-operation-for-field.d.res и build-operation-for-field.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'kind': 1, 'field': 1, 'models': 1, 'ignore': 1, 'depthLimit': 1, 'circularReferenceDepth': 1, 'argNames': 1, 'selectedFields': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\node_modules\@graphql-tools\utils\typings filterSchema.d.res и filterSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'typeFilter': 1, 'fieldFilter': 1, 'rootFieldFilter': 1, 'objectFieldFilter': 1, 'interfaceFieldFilter': 1, 'inputObjectFieldFilter': 1, 'argumentFilter': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\typings addMocksToSchema.d.res и addMocksToSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'store': 1, 'mocks': 1, 'typePolicies': 1, 'resolvers': 1, 'preserveResolvers': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\mock\typings pagination.d.res и pagination.d.res_land:
#   В .res есть, а в .res_land не хватает: {'cursorFn': 1, 'applyOnNodes': 1, 'allNodesFn': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\schema\typings makeExecutableSchema.d.res и makeExecutableSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'resolverValidationOptions': 1, 'inheritResolversFromInterfaces': 1, 'updateResolversInPlace': 1, 'schemaExtensions': 1, 'defaultFieldResolver': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\utils\typings filterSchema.d.res и filterSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'typeFilter': 1, 'fieldFilter': 1, 'rootFieldFilter': 1, 'objectFieldFilter': 1, 'interfaceFieldFilter': 1, 'inputObjectFieldFilter': 1, 'argumentFilter': 1, 'directiveFilter': 1, 'enumValueFilter': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\@graphql-tools\utils\typings mergeIncrementalResult.d.res и mergeIncrementalResult.d.res_land:
#   В .res есть, а в .res_land не хватает: {'incrementalResult': 1, 'executionResult': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\agent-base\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'defaultPort': 2, 'protocol': 2, 'callback': 1, 'addRequest': 1, 'freeSocket': 1, 'destroy': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\dist\plugin\schemaReporting index.d.res и index.d.res_land:
#   В .res есть, а в .res_land не хватает: {'initialDelayMaxMs': 1, 'overrideReportedSchema': 1, 'endpointUrl': 1, 'fetcher': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\dist\plugin\usageReporting operationDerivedDataCache.d.res и operationDerivedDataCache.d.res_land:
#   В .res есть, а в .res_land не хватает: {'logger': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\dist\utils pluginTestHarness.d.res и pluginTestHarness.d.res_land:
#   В .res есть, а в .res_land не хватает: {'pluginInstance': 1, 'schema': 1, 'logger': 1, 'graphqlRequest': 1, 'overallCachePolicy': 1, 'executor': 1, 'context': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\node_modules\@graphql-tools\schema\typings makeExecutableSchema.d.res и makeExecutableSchema.d.res_land:
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'resolverValidationOptions': 1, 'parseOptions': 1, 'inheritResolversFromInterfaces': 1, 'pruningOptions': 1, 'updateResolversInPlace': 1, 'schemaExtensions': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\node_modules\@graphql-tools\utils\typings build-operation-for-field.d.res и build-operation-for-field.d.res_land:
#   В .res есть, а в .res_land не хватает: {'schema': 1, 'kind': 1, 'field': 1, 'models': 1, 'ignore': 1, 'depthLimit': 1, 'circularReferenceDepth': 1, 'argNames': 1, 'selectedFields': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src ApolloServer.res и ApolloServer.res_land:
#   В .res есть, а в .res_land не хватает: {'Field': 1, 'constructor': 2, 'start': 1, '_start': 1, 'maybeRegisterTerminationSignalHandlers': 1, '_ensureStarted': 1, 'ensureStarted': 1, 'assertStarted': 1, 'logStartupError': 1, 'constructSchema': 1, 'maybeAddMocksToConstructedSchema': 1, 'generateSchemaDerivedData': 1, 'stop': 1, 'serverlessFramework': 1, 'ensurePluginInstantiation': 1, 'graphQLServerOptions': 1, 'executeOperation': 1, 'getLandingPage': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src runHttpQuery.res и runHttpQuery.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'requestDidStart': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin traceTreeBuilder.res и traceTreeBuilder.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'startTiming': 1, 'stopTiming': 1, 'willResolveField': 1, 'didEncounterErrors': 1, 'addProtobufError': 1, 'newNode': 1, 'ensureParentNode': 1, 'rewriteAndNormalizeError': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\drainHttpServer stoppable.res и stoppable.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'stop': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\schemaReporting schemaReporter.res и schemaReporter.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'stopped': 1, 'start': 1, 'stop': 1, 'sendOneReportAndScheduleNext': 1, 'reportSchema': 1, 'apolloQuery': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\usageReporting durationHistogram.res и durationHistogram.res_land:
#   В .res есть, а в .res_land не хватает: {'toArray': 1, 'durationToBucket': 1, 'incrementDuration': 1, 'incrementBucket': 1, 'combine': 1, 'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\usageReporting iterateOverTrace.res и iterateOverTrace.res_land:
#   В .res есть, а в .res_land не хватает: {'toArray': 3, 'child': 3, 'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\usageReporting stats.res и stats.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 4, 'ensureCountsAreIntegers': 6, 'addTrace': 3, 'getTracesAndStats': 1, 'toArray': 1, 'getContextualizedStats': 1, 'getTypeStat': 1, 'getChild': 1, 'getFieldStat': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\utils dispatcher.res и dispatcher.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'callTargets': 1, 'hasHook': 1, 'invokeHook': 1, 'invokeHooksUntilNonNull': 1, 'invokeDidStartHook': 1, 'invokeSyncDidStartHook': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\utils schemaManager.res и schemaManager.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 2, 'start': 1, 'onSchemaLoadOrUpdate': 1, 'getSchemaDerivedData': 1, 'stop': 1, 'processSchemaLoadOrUpdateEvent': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\utils UnboundedCache.res и UnboundedCache.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'get': 1, 'set': 1, 'delete': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-errors\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 8, 'toJSON': 1, 'toString': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-express\src ApolloServer.res и ApolloServer.res_land:
#   В .res есть, а в .res_land не хватает: {'createGraphQLServerOptions': 1, 'applyMiddleware': 1, 'getMiddleware': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\graphql-tag\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'gql': 1, 'resetCaches': 1, 'disableFragmentWarnings': 1, 'enableExperimentalFragmentVariables': 1, 'disableExperimentalFragmentVariables': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\graphql-tag\src tests.res и tests.res_land:
#   В .res есть, а в .res_land не хватает: {'cacheable': 12}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\highlight.js\types index.d.res и index.d.res_land:
#   В .res есть, а в .res_land не хватает: {'languageName': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\ip-address\src address-error.res и address-error.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\ip-address\src ip-address.res и ip-address.res_land:
#   В .res есть, а в .res_land не хватает: {'helpers': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\ip-address\src ipv4.res и ipv4.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'isValid': 1, 'parse': 1, 'correctForm': 1, 'fromHex': 1, 'fromInteger': 1, 'fromArpa': 1, 'toHex': 1, 'toArray': 1, 'toGroup6': 1, 'bigInteger': 1, '_startAddress': 1, 'startAddress': 1, 'startAddressExclusive': 1, '_endAddress': 1, 'endAddress': 1, 'endAddressExclusive': 1, 'fromBigInteger': 1, 'mask': 1, 'getBitsBase2': 1, 'reverseForm': 1, 'isMulticast': 1, 'binaryZeroPad': 1, 'groupForV6': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\ip-address\src ipv6.res и ipv6.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'isValid': 1, 'fromBigInteger': 1, 'fromURL': 1, 'fromAddress4': 1, 'fromArpa': 1, 'microsoftTranscription': 1, 'mask': 1, 'possibleSubnets': 1, '_startAddress': 1, 'startAddress': 1, 'startAddressExclusive': 1, '_endAddress': 1, 'endAddress': 1, 'endAddressExclusive': 1, 'getScope': 1, 'getType': 1, 'getBits': 1, 'getBitsBase2': 1, 'getBitsBase16': 1, 'getBitsPastSubnet': 1, 'reverseForm': 1, 'correctForm': 1, 'binaryZeroPad': 1, 'parse4in6': 1, 'parse': 1, 'canonicalForm': 1, 'decimal': 1, 'bigInteger': 1, 'to4': 1, 'to4in6': 1, 'inspectTeredo': 1, 'inspect6to4': 1, 'to6to4': 1, 'toByteArray': 1, 'toUnsignedByteArray': 1, 'fromByteArray': 1, 'fromUnsignedByteArray': 1, 'isCanonical': 1, 'isLinkLocal': 1, 'isMulticast': 1, 'is4': 1, 'isTeredo': 1, 'is6to4': 1, 'isLoopback': 1, 'href': 1, 'link': 1, 'group': 1, 'regularExpressionString': 1, 'regularExpression': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\type-graphql\build\typings\helpers findType.d.res и findType.d.res_land:
#   В .res есть, а в .res_land не хватает: {'metadataKey': 1, 'prototype': 1, 'propertyKey': 1, 'parameterIndex': 1, 'argName': 1, 'returnTypeFunc': 1, 'typeOptions': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\type-graphql\build\typings\helpers params.d.res и params.d.res_land:
#   В .res есть, а в .res_land не хватает: {'prototype': 1, 'propertyKey': 1, 'parameterIndex': 1, 'argName': 1, 'returnTypeFunc': 1, 'options': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\typeorm\node_modules\glob\dist\commonjs index.d.res и index.d.res_land:
#   В .res есть, а в .res_land не хватает: {'windowsPathsNoEscape': 2}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\typeorm\node_modules\minimatch\dist\commonjs escape.d.res и escape.d.res_land:
#   В .res есть, а в .res_land не хватает: {'windowsPathsNoEscape': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\typeorm\node_modules\minimatch\dist\commonjs index.d.res и index.d.res_land:
#   В .res есть, а в .res_land не хватает: {'windowsPathsNoEscape': 2}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\typeorm\node_modules\minimatch\dist\commonjs unescape.d.res и unescape.d.res_land:
#   В .res есть, а в .res_land не хватает: {'windowsPathsNoEscape': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\node_modules\typescript\lib typescript.d.res и typescript.d.res_land:
#   В .res есть, а в .res_land не хватает: {'rootNames': 1, 'options': 1, 'configFileParsingDiagnostics': 1, 'projectReferences': 1, 'host': 1, 'createProgram': 1}
# ❌ Разница в файлах e:\phd\ts_res\graphql-server\src\resolvers UserResolver.res и UserResolver.res_land:
#   В .res есть, а в .res_land не хватает: {'users': 1, 'user': 1, 'createUser': 1, 'deleteUser': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow setup-tests.res и setup-tests.res_land:
#   В .res есть, а в .res_land не хватает: {'asyncUtilTimeout': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\integration ai-assistant.res и ai-assistant.res_land:
#   В .res есть, а в .res_land не хватает: {'datasetId': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\integration class-selection-popover.res и class-selection-popover.res_land:
#   В .res есть, а в .res_land не хватает: {'imageId': 1, 'labelClassId': 1, 'datasetId': 2}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\integration classification.res и classification.res_land:
#   В .res есть, а в .res_land не хватает: {'datasetId': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\integration invitation-manager.res и invitation-manager.res_land:
#   В .res есть, а в .res_land не хватает: {'inviteUrl': 6}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\integration polygon-drawing.res и polygon-drawing.res_land:
#   В .res есть, а в .res_land не хватает: {'pointerId': 3, 'name': 1, 'datasetId': 2}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\plugins index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'webpackOptions': 1, 'clearDb': 1, 'performLogin': 1, 'createWorkspace': 1, 'createWorkspaceAndDatasets': 1, 'inviteUser': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\utils graphql.res и graphql.res_land:
#   В .res есть, а в .res_land не хватает: {'mutation': 4, 'variables': 3, 'name': 2, 'color': 1, 'datasetId': 2}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\cypress\utils jwt.res и jwt.res_land:
#   В .res есть, а в .res_land не хватает: {'iat': 1, 'token': 1, 'secret': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src dataset.res и dataset.res_land:
#   В .res есть, а в .res_land не хватает: {'datasetId': 1, 'user': 15, 'repository': 10, 'id': 2, 'createdAt': 1, 'updatedAt': 1, 'name': 1, 'dataset': 1, 'datasets': 1, 'searchDataset': 1, 'createDataset': 1, 'updateDataset': 1, 'deleteDataset': 1, 'images': 1, 'labels': 1, 'labelClasses': 1, 'workspace': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src iog-inference.res и iog-inference.res_land:
#   В .res есть, а в .res_land не хватает: {'variables': 1, 'coordinates': 1, 'geometry': 3, 'x': 4, 'y': 4, 'id': 3, 'imageUrl': 2, 'height': 2, 'width': 2, 'smartToolInput': 2, 'repository': 2, 'user': 2, 'req': 2, 'data': 1, 'createIogLabel': 1, 'updateIogLabel': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src label-class.res и label-class.res_land:
#   В .res есть, а в .res_land не хватает: {'user': 21, 'repository': 11, 'datasetId': 4, 'id': 7, 'name': 1, 'createdAt': 1, 'updatedAt': 1, 'labelClasses': 2, 'in': 1, 'labelClass': 1, 'labelClassesAggregates': 2, 'labelClassExists': 1, 'createLabelClass': 1, 'createManyLabelClasses': 1, 'updateLabelClass': 1, 'deleteLabelClass': 1, 'reorderLabelClass': 1, 'labels': 1, 'dataset': 1, 'totalCount': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src label.res и label.res_land:
#   В .res есть, а в .res_land не хватает: {'id': 10, 'repository': 7, 'user': 9, 'labelClassId': 1, 'imageId': 1, 'x': 2, 'y': 2, 'width': 2, 'height': 2, 'geometry': 2, 'smartToolInput': 1, 'where': 1, 'label': 1, 'labelsAggregates': 3, 'createLabel': 1, 'deleteLabel': 1, 'deleteManyLabels': 1, 'updateLabel': 1, 'labelClass': 1, 'totalCount': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src scalars.res и scalars.res_land:
#   В .res есть, а в .res_land не хватает: {'JSON': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src upload.res и upload.res_land:
#   В .res есть, а в .res_land не хватает: {'repository': 1, 'req': 1, 'getUploadTarget': 1, '__resolveType': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src\export common.res и common.res_land:
#   В .res есть, а в .res_land не хватает: {'ResolverTest_class_1_func_1': 1, 'ResolverTest_class_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\common-resolvers\src\export export-to-csv.fixtures.res и export-to-csv.fixtures.res_land:
# ...
#   В .res есть, а в .res_land не хватает: {'id': 1, 'labelClasses': 1, 'labelClassesAggregates': 1, 'data': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\connectors\undo-store\effects\cache-updates delete-label-mutation-update.res и delete-label-mutation-update.res_land:
#   В .res есть, а в .res_land не хватает: {'data': 2, 'id': 1, 'imageId': 1, 'labelClass': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\connectors\undo-store\effects\cache-updates update-label-class-of-label.res и update-label-class-of-label.res_land:
#   В .res есть, а в .res_land не хватает: {'data': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\hooks use-dataset-image.res и use-dataset-image.res_land:
#   В .res есть, а в .res_land не хватает: {'id': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\hooks use-dataset.res и use-dataset.res_land:
#   В .res есть, а в .res_land не хватает: {'slug': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\hooks use-image-navigation.fixtures.res и use-image-navigation.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'query': 1, 'images': 1, 'delay': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\hooks use-image-pre-fetching.res и use-image-pre-fetching.res_land:
#   В .res есть, а в .res_land не хватает: {'canFetchNext': 1, 'canFetchPrevious': 1, 'imageId': 2}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\hooks use-images-navigation.res и use-images-navigation.res_land:
#   В .res есть, а в .res_land не хватает: {'images': 3, 'imagesCount': 3, 'currentImageIndex': 2, 'previousImageId': 2, 'nextImageId': 2, 'id': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api graphql.res и graphql.res_land:
#   В .res_land есть, а в .res не хватает: {'bodyParser': 1}
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'req': 4, 'repository': 1, 'session': 1, 'res': 2, 'schema': 1, 'document': 1, 'variableValues': 1, 'operationName': 1, 'error': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api\auth [...nextauth].res и [...nextauth].res_land:
#   В .res есть, а в .res_land не хватает: {'session': 1, 'error': 1, 'warn': 1, 'debug': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api\downloads [...id].res и [...id].res_land:
#   В .res_land есть, а в .res не хватает: {'bodyParser': 1}
#   В .res есть, а в .res_land не хватает: {'onError': 1, 'onNoMatch': 1, 'req': 1, 'Bucket': 1, 'Key': 1, 'expiresIn': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api\email view.res и view.res_land:
#   В .res есть, а в .res_land не хватает: {'signin': 1, 'signup': 1, 'invitation': 1, 'default': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api\stripe webhooks.res и webhooks.res_land:
#   В .res_land есть, а в .res не хватает: {'bodyParser': 1}
#   В .res есть, а в .res_land не хватает: {'slug': 1, 'plan': 1, 'status': 5, 'workspaceSlug': 4, 'workspacePlan': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\pages\api\uploads [...id].res и [...id].res_land:
#   В .res_land есть, а в .res не хватает: {'bodyParser': 1}
#   В .res есть, а в .res_land не хватает: {'onError': 1, 'onNoMatch': 1, 'req': 2}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils deferred.res и deferred.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'reset': 1, 'waitForValue': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils google-analytics.res и google-analytics.res_land:
#   В .res есть, а в .res_land не хватает: {'page_path': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils mock-window.res и mock-window.res_land:
#   В .res есть, а в .res_land не хватает: {'value': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils query-param-get-set.res и query-param-get-set.res_land:
#   В .res есть, а в .res_land не хватает: {'replace': 1, 'pathname': 1, 'query': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils upload-file.res и upload-file.res_land:
#   В .res есть, а в .res_land не хватает: {'mutation': 1, 'key': 2, 'body': 1, 'file': 1, 'apolloClient': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\email send-verification-request.res и send-verification-request.res_land:
#   В .res есть, а в .res_land не хватает: {'to': 1, 'from': 2, 'url': 2, 'origin': 1, 'identifier': 1, 'server': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\fixtures dataset.fixtures.res и dataset.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'workspace': 4}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\fixtures image.fixtures.res и image.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'dataset': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\fixtures label-class.fixtures.res и label-class.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'dataset': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\fixtures label.fixtures.res и label.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'labelClass': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\fixtures user.fixtures.res и user.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'query': 1, 'user': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\tests mock-use-query-params.res и mock-use-query-params.res_land:
#   В .res есть, а в .res_land не хватает: {'useQueryParam': 1, 'withDefault': 1, 'StringParam': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\tests mock-workspace.res и mock-workspace.res_land:
#   В .res есть, а в .res_land не хватает: {'id': 1, 'status': 3, 'data': 1, 'userId': 1, 'workspaceSlug': 1, 'query': 1, 'useSession': 1}
# ❌ Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\tests router-mocks.res и router-mocks.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'replace': 1, 'push': 1, 'reload': 1, 'back': 1, 'prefetch': 1, 'beforePopState': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'graphqlServer': 1, 'httpServer': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\models requestLog.model.res и requestLog.model.res_land:
#   В .res есть, а в .res_land не хватает: {'enum': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\models user.model.res и user.model.res_land:
#   В .res есть, а в .res_land не хватает: {'enum': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\services author.service.res и author.service.res_land:
#   В .res есть, а в .res_land не хватает: {'$in': 1, 'limit': 2, 'skip': 1, 'currentPage': 1, 'items': 1, 'totalItems': 1, 'totalPages': 1, '_id': 2, 'count': 1, 'deleteById': 1, 'findAll': 1, 'findById': 1, 'findByIds': 1, 'findOneOrFail': 1, 'findOrCreate': 1, 'findPaginate': 1, 'update': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\services language.service.res и language.service.res_land:
#   В .res есть, а в .res_land не хватает: {'limit': 2, 'populate': 2, 'skip': 1, 'currentPage': 1, 'items': 1, 'totalItems': 1, 'totalPages': 1, '_id': 3, '$in': 1, 'yearGroup': 2, 'count': 1, 'countByYearGroup': 1, 'deleteById': 1, 'findAll': 1, 'findByAuthor': 1, 'findById': 1, 'findByIdOrName': 1, 'findByIds': 1, 'findByYearGroup': 1, 'findOneOrFail': 1, 'findOrCreate': 1, 'findPaginate': 1, 'findSuccessors': 1, 'update': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\services requestLog.service.res и requestLog.service.res_land:
#   В .res есть, а в .res_land не хватает: {'create': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\services user.service.res и user.service.res_land:
#   В .res есть, а в .res_land не хватает: {'email': 1, '_id': 2, 'count': 1, 'create': 1, 'deleteById': 1, 'findAll': 1, 'findByEmail': 1, 'findById': 1, 'findOneOrFail': 1, 'update': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\domain\services yearGroup.service.res и yearGroup.service.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 4, 'count': 1, 'createNotListedGroup': 1, 'findAll': 1, 'findById': 1, 'findByName': 1, 'findNotListedGroup': 1, 'findOrCreate': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\graphql server.res и server.res_land:
#   В .res есть, а в .res_land не хватает: {'resolvers': 1, 'schema': 2, 'context': 1, 'app': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\graphql\resolvers index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'id': 3, 'languages': 2, 'Date': 1, 'authors': 2, 'predecessors': 1, 'successors': 1, 'yearGroup': 1, 'allAuthors': 1, 'allLanguages': 1, 'allYearGroups': 1, 'oneAuthor': 1, 'oneLanguage': 1, 'oneYearGroup': 1, 'languageCount': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\graphql\scalars date.res и date.res_land:
#   В .res есть, а в .res_land не хватает: {'parseLiteral': 1, 'parseValue': 1, 'serialize': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\graphql\utils requestPlugin.res и requestPlugin.res_land:
#   В .res есть, а в .res_land не хватает: {'requestDidStart': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\graphql\utils sentryPlugin.res и sentryPlugin.res_land:
#   В .res есть, а в .res_land не хватает: {'requestDidStart': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\rest\controllers author.controller.res и author.controller.res_land:
#   В .res есть, а в .res_land не хватает: {'_id': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\rest\controllers language.controller.res и language.controller.res_land:
#   В .res есть, а в .res_land не хватает: {'_id': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\rest\controllers stat.controller.res и stat.controller.res_land:
#   В .res есть, а в .res_land не хватает: {'author': 1, 'language': 1, 'user': 1, 'yearGroup': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\rest\controllers user.controller.res и user.controller.res_land:
#   В .res есть, а в .res_land не хватает: {'message': 4, 'email': 2, 'name': 2, 'role': 2, 'expiresIn': 2, 'token': 1, '_id': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\rest\controllers yearGroup.controller.res и yearGroup.controller.res_land:
#   В .res есть, а в .res_land не хватает: {'data': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core logger.res и logger.res_land:
#   В .res есть, а в .res_land не хватает: {'dirname': 1, 'error': 1, 'info': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core scraper.res и scraper.res_land:
#   В .res есть, а в .res_land не хватает: {'yearGroup': 1, 'name': 2, 'link': 1, 'authors': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core sentry.res и sentry.res_land:
#   В .res есть, а в .res_land не хватает: {'dsn': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core\middleware authMiddleware.res и authMiddleware.res_land:
#   В .res есть, а в .res_land не хватает: {'message': 3}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core\middleware errorMiddleware.res и errorMiddleware.res_land:
#   В .res есть, а в .res_land не хватает: {'message': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core\middleware logRequestMiddleware.res и logRequestMiddleware.res_land:
#   В .res есть, а в .res_land не хватает: {'endpoint': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core\middleware notFoundMiddleware.res и notFoundMiddleware.res_land:
#   В .res есть, а в .res_land не хватает: {'message': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\core\middleware rateLimiterMiddleware.res и rateLimiterMiddleware.res_land:
#   В .res есть, а в .res_land не хватает: {'duration': 1, 'points': 1, 'message': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\utils sanitizeData.res и sanitizeData.res_land:
#   В .res есть, а в .res_land не хватает: {'predecessors': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\shared\utils scraper.res и scraper.res_land:
#   В .res есть, а в .res_land не хватает: {'name': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\__tests__\shared\utils helpers.test.res и helpers.test.res_land:
#   В .res есть, а в .res_land не хватает: {'fields': 1, 'keyword': 1, 'page': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\backend\app\__tests__\utils testUtils.res и testUtils.res_land:
#   В .res есть, а в .res_land не хватает: {'response': 1, 'baseURL': 1, 'apiClient': 1, 'httpServer': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\hooks useAuth.res и useAuth.res_land:
#   В .res есть, а в .res_land не хватает: {'deleteToken': 1, 'loading': 1, 'saveToken': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\hooks useLoadLanguageFormData.res и useLoadLanguageFormData.res_land:
#   В .res есть, а в .res_land не хватает: {'authorData': 1, 'isLoading': 1, 'languageData': 1, 'yearGroupData': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\hooks\request\query useRetrieveAuthors.res и useRetrieveAuthors.res_land:
#   В .res есть, а в .res_land не хватает: {'page': 1, 'search': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\hooks\request\query useRetrieveLanguages.res и useRetrieveLanguages.res_land:
#   В .res есть, а в .res_land не хватает: {'yearGroup': 1, 'page': 1, 'search': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\utils constants.res и constants.res_land:
#   В .res есть, а в .res_land не хватает: {'maxCharacters': 1, 'minCharacters': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\utils gtag.res и gtag.res_land:
#   В .res есть, а в .res_land не хватает: {'page_path': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\__tests__ cypress.config.res и cypress.config.res_land:
#   В .res есть, а в .res_land не хватает: {'setupNodeEvents': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\__tests__\cypress\models utils.res и utils.res_land:
#   В .res есть, а в .res_land не хватает: {'ResolverTest_class_1_func_1': 1, 'ResolverTest_class_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\__tests__\cypress\models website.res и website.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'expectHomePageToBeDisplayed': 1, 'navigateToDocumentationPage': 1, 'navigateToPlaygroundPage': 1, 'navigateToHomePage': 1, 'goToDashboard': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\__tests__\mocks browser.res и browser.res_land:
#   В .res есть, а в .res_land не хватает: {'rest': 1, 'worker': 1}
# ❌ Разница в файлах e:\phd\ts_res\prolang-api\frontend\__tests__\mocks handlers.res и handlers.res_land:
#   В .res есть, а в .res_land не хватает: {'data': 3}
# ❌ Разница в файлах e:\phd\ts_res\test server.res и server.res_land:
#   В .res_land есть, а в .res не хватает: {'user': 3}
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'schema': 1, 'url': 1}
# ❌ Разница в файлах e:\phd\ts_res\test server2.res и server2.res_land:
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'schema': 1, 'url': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\1 server.res и server.res_land:
#   В .res_land есть, а в .res не хватает: {'user': 3}
#   В .res есть, а в .res_land не хватает: {'typeDefs': 1, 'resolvers': 1, 'schema': 1, 'url': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\apollo-server\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'createServerInfo': 1, 'applyMiddleware': 1, 'start': 1, 'listen': 1}
# OK: 2464 (87.59331674369001%), BAD: 349, TOTAL: 2813

# %%
87.59331674369001
# Out:
# 87.59331674369001

# %%
68.64
