# %%
import os
from collections import Counter

# %%
def read_file_lines(filepath):
    """Считывает строки из файла и возвращает их в виде словаря с количеством вхождений."""
    if not os.path.exists(filepath):
        return None
    with open(filepath, 'r', encoding='utf-8') as file:
        return Counter(line.strip() for line in file)

# %%
def compare_files(directory):
    total = 0
    ok = 0
    idx = 0
    """Рекурсивно обходит файлы в указанной папке и сравнивает пары файлов .res и .res_land."""
    for root, _, files in os.walk(directory):
        for filename in files:
            if filename.endswith(".res") and not filename.endswith(".res_land"):
                base_name = filename[:-4]  # Убираем расширение .res
                res_file = os.path.join(root, filename)
                res_land_file = os.path.join(root, f"{base_name}.res_land")
                
                lines_res = read_file_lines(res_file)
                lines_res_land = read_file_lines(res_land_file)
                
                total+=1
                
                if lines_res is None or lines_res_land is None:
                    print(f"Файл отсутствует: {res_file if lines_res is None else res_land_file}")
                    continue
                
                if lines_res == lines_res_land:
                    ok += 1
                    #print(f"✔ Файлы {filename} и {base_name}.res_land совпадают")
                else:
                    missing_in_res = {line: count for line, count in lines_res_land.items() if count > lines_res.get(line, 0)}
                    missing_in_res_land = {line: count for line, count in lines_res.items() if count > lines_res_land.get(line, 0)}
                    idx+=1
                    print(f"[{idx}] Разница в файлах {root} {filename} и {base_name}.res_land:")
                    if missing_in_res:
                        print("  В .res_land есть, а в .res не хватает:", missing_in_res)
                    if missing_in_res_land:
                        print("  В .res есть, а в .res_land не хватает:", missing_in_res_land)
    print(f"OK: {ok} ({ok/total*100}%), BAD: {total-ok}, TOTAL: {total}")

# %%
directory_path = "e:\\phd\\ts_res"
compare_files(directory_path)
# Out:
# [1] Разница в файлах e:\phd\ts_res\graphql-server\node_modules\agent-base\src index.res и index.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'defaultPort': 2, 'protocol': 2, 'callback': 1, 'addRequest': 1, 'freeSocket': 1, 'destroy': 1}
# [2] Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\plugin\schemaReporting schemaReporter.res и schemaReporter.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'stopped': 1, 'start': 1, 'stop': 1, 'sendOneReportAndScheduleNext': 1, 'reportSchema': 1, 'apolloQuery': 1}
# [3] Разница в файлах e:\phd\ts_res\graphql-server\node_modules\apollo-server-core\src\utils schemaManager.res и schemaManager.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 2, 'start': 1, 'onSchemaLoadOrUpdate': 1, 'getSchemaDerivedData': 1, 'stop': 1, 'processSchemaLoadOrUpdateEvent': 1}
# [4] Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\components\labeling-tool\image-navigation image-navigation-tool.fixtures.res и image-navigation-tool.fixtures.res_land:
#   В .res есть, а в .res_land не хватает: {'dataset': 1}
# [5] Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\components\labeling-tool\openlayers-map\iog resize-canvas-interaction.res и resize-canvas-interaction.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'handleDownEvent': 1, 'handleUpEvent': 1, 'handleDragEvent': 1, 'handleMoveEvent': 1, 'stopDown': 1}
# [6] Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\components\labeling-tool\openlayers-map\select-and-modify-feature resize-and-translate-box-interaction.res и resize-and-translate-box-interaction.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'handleDownEvent': 1, 'handleUpEvent': 1, 'handleDragEvent': 1, 'handleMoveEvent': 1, 'stopDown': 1}
# [7] Разница в файлах e:\phd\ts_res\labelflow\typescript\web\src\utils\tests router-mocks.res и router-mocks.res_land:
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'replace': 1, 'push': 1, 'reload': 1, 'back': 1, 'prefetch': 1, 'beforePopState': 1}
# OK: 2806 (99.75115535015998%), BAD: 7, TOTAL: 2813

# %%
99.71560611446854
# Out:
# 99.71560611446854
