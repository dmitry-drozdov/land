# %%
import os
from collections import Counter

# %%
def read_file_lines(filepath):
    """Считывает строки из файла и возвращает их в виде словаря с количеством вхождений."""
    if not os.path.exists(filepath):
        return None
    with open(filepath, 'r', encoding='utf-8') as file:
        return Counter(line.strip() for line in file)

# %%
def compare_files(directory):
    total = 0
    ok = 0
    """Рекурсивно обходит файлы в указанной папке и сравнивает пары файлов .res и .res_land."""
    for root, _, files in os.walk(directory):
        for filename in files:
            if filename.endswith(".res") and not filename.endswith(".res_land"):
                base_name = filename[:-4]  # Убираем расширение .res
                res_file = os.path.join(root, filename)
                res_land_file = os.path.join(root, f"{base_name}.res_land")
                
                lines_res = read_file_lines(res_file)
                lines_res_land = read_file_lines(res_land_file)
                
                total+=1
                
                if lines_res is None or lines_res_land is None:
                    print(f"Файл отсутствует: {res_file if lines_res is None else res_land_file}")
                    continue
                
                if lines_res == lines_res_land:
                    ok += 1
                    #print(f"✔ Файлы {filename} и {base_name}.res_land совпадают")
                else:
                    missing_in_res = {line: count for line, count in lines_res_land.items() if count > lines_res.get(line, 0)}
                    missing_in_res_land = {line: count for line, count in lines_res.items() if count > lines_res_land.get(line, 0)}
                    print(f"❌ Разница в файлах {root} {filename} и {base_name}.res_land:")
                    if missing_in_res:
                        print("  В .res_land есть, а в .res не хватает:", missing_in_res)
                    if missing_in_res_land:
                        print("  В .res есть, а в .res_land не хватает:", missing_in_res_land)
    print(f"OK: {ok} ({ok/total*100}%), BAD: {total-ok}, TOTAL: {total}")

# %%
directory_path = "e:\\phd\\ts_res"
compare_files(directory_path)
# Out:
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service schema.res и schema.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\address\utils\clientSchema Address.res и Address.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\address\utils\clientSchema AddressInjection.res и AddressInjection.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\address\utils\clientSchema AddressSource.res и AddressSource.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\address\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\user\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\address-service\domains\user\utils\clientSchema User.res и User.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo codegen.res и codegen.res_land:
#   В .res_land есть, а в .res не хватает: {'content': 1, 'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo global.d.res и global.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo next-env.d.res и next-env.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo schema.res и schema.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo sentry.client.config.res и sentry.client.config.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo sentry.server.config.res и sentry.server.config.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\components\PayConfirmScreen index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\components\payments PaymentsSumTable.res и PaymentsSumTable.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\hooks usePaymentsTableColumns.res и usePaymentsTableColumns.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\hooks usePaymentsTableFilters.res и usePaymentsTableFilters.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema AcquiringIntegration.res и AcquiringIntegration.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema AcquiringIntegrationAccessRight.res и AcquiringIntegrationAccessRight.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema AcquiringIntegrationContext.res и AcquiringIntegrationContext.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema MultiPayment.res и MultiPayment.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema Payment.res и Payment.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema PaymentsFilterTemplate.res и PaymentsFilterTemplate.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\acquiring\utils\clientSchema search.res и search.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components CustomChart.res и CustomChart.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components TicketChart.res и TicketChart.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components TicketChart.spec.res и TicketChart.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\payment dataMappers.res и dataMappers.res_land:
#   В .res_land есть, а в .res не хватает: {'chart': 3, 'table': 1, 'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\payment PaymentChart.res и PaymentChart.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'getChartConfig': 1, 'getTableConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\resident dataMappers.res и dataMappers.res_land:
#   В .res_land есть, а в .res не хватает: {'chart': 1, 'table': 1, 'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\resident ResidentChart.res и ResidentChart.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'getChartConfig': 1, 'getTableConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\components\charts\ticket dataMappers.res и dataMappers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'chart': 3, 'table': 3}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'filter': 1, 'viewMode': 2, 'ticketType': 1, 'mainGroup': 1, 'legend': 1, 'animationEnabled': 1, 'axisData': 1, 'tooltip': 1, 'series': 1, 'chartOptions': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\analytics\utils helpers.spec.res и helpers.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\hooks useTableFilters.res и useTableFilters.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankAccount.res и BankAccount.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankAccountReport.res и BankAccountReport.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankCategory.res и BankCategory.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankContractorAccount.res и BankContractorAccount.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankCostItem.res и BankCostItem.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankIntegration.res и BankIntegration.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankIntegrationAccessRight.res и BankIntegrationAccessRight.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankIntegrationAccountContext.res и BankIntegrationAccountContext.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankIntegrationOrganizationContext.res и BankIntegrationOrganizationContext.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema BankTransaction.res и BankTransaction.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\banking\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\components\BillingPageContent ContextProvider.res и ContextProvider.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'refetchBilling': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\hooks useOnboardingProgress.res и useOnboardingProgress.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\hooks useQueryTab.res и useQueryTab.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\hooks useReceiptTableColumns.res и useReceiptTableColumns.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingAccount.res и BillingAccount.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingCategory.res и BillingCategory.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingIntegration.res и BillingIntegration.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingIntegrationAccessRight.res и BillingIntegrationAccessRight.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingIntegrationOrganizationContext.res и BillingIntegrationOrganizationContext.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingIntegrationProblem.res и BillingIntegrationProblem.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingProperty.res и BillingProperty.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingReceipt.res и BillingReceipt.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingReceiptFile.res и BillingReceiptFile.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingReceiptForOrganization.res и BillingReceiptForOrganization.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema BillingRecipient.res и BillingRecipient.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\billing\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components BaseChart.res и BaseChart.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components FocusContainer.res и FocusContainer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components FrontLayerContainer.res и FrontLayerContainer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components TableFiltersContainer.res и TableFiltersContainer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components wdyr.res и wdyr.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\BaseSearchInput useInitialValueGetter.res и useInitialValueGetter.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\BaseSearchInput useSelectCareeteControls.res и useSelectCareeteControls.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\Carousel index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\ChangeHistory\HistoricalChange types.res и types.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\containers\BaseLayout index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\containers\BaseLayout\components styles.res и styles.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\containers\EmptyLayout index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\Form FormItem.res и FormItem.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\GraphQlSearchInput index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\PostMessageProvider index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\PostMessageProvider types.res и types.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\PostMessageProvider validators.res и validators.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'CondoWebAppGetActiveProgressBars': 1, 'CondoWebAppGetLaunchParams': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\tasks TaskLauncher.res и TaskLauncher.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers AmplitudeInstance.res и AmplitudeInstance.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'init': 1, 'logInstanceEvent': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers TrackerInstance.res и TrackerInstance.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'logEvent': 1, 'eventName': 1, 'eventProperties': 1, 'denyDuplicates': 1, 'isNeedToSendEvent': 1, '_getLogEventPermissionFromConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\components\trackers TrackerInstance.spec.res и TrackerInstance.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'TRACKER_DOMAIN': 1, 'constructor': 1, 'init': 1, 'logInstanceEvent': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useCheckboxSearch.res и useCheckboxSearch.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useContainerSize.res и useContainerSize.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useDateRangeSearch.res и useDateRangeSearch.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useDownloadFileFromServer.res и useDownloadFileFromServer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useImporter.res и useImporter.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks usePreviousQueryParams.res и usePreviousQueryParams.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'set': 1, 'get': 1, 'getAll': 1, 'getStorageKey': 1, 'getPageKey': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useQueryMappers.res и useQueryMappers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useQueryTab.res и useQueryTab.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useSearch.res и useSearch.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useValidations.res и useValidations.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\hooks useWindowSize.res и useWindowSize.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\types index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils addressApi.res и addressApi.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'getSuggestions': 1, 'getRawAddress': 1, 'cacheRawAddress': 1, 'setAddressSuggestionsConfig': 1, 'setSessionConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils date.utils.res и date.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils excel.utils.res и excel.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'flat': 1, 'floor': 1, 'section': 1, 'address': 1, 'name': 1, 'email': 1, 'phone': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils filters.utils.res и filters.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils filters.utils.spec.res и filters.utils.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils helpers.spec.res и helpers.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils importer.res и importer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'import': 1, 'break': 1, 'onError': 1, 'onFinish': 1, 'onRowProcessed': 1, 'onRowFailed': 1, 'onProgressUpdate': 1, 'isColumnsValid': 1, 'parseAndValidateRow': 1, 'updateProgress': 1, 'createRecord': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils importer.spec.res и importer.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'message': 7, 'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils mutations.utils.res и mutations.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils nonNull.res и nonNull.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils pdf.res и pdf.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils query.res и query.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils select.utils.res и select.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils tables.utils.res и tables.utils.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils tables.utils.spec.res и tables.utils.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils timer.res и timer.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils typeGuards.res и typeGuards.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\clientSchema messagesImporter.res и messagesImporter.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\next apollo.res и apollo.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'uri': 1, 'cacheConfig': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\next helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\next ssr.res и ssr.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\common\utils\next types.res и types.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\hooks useContactExportTaskUIInterface.res и useContactExportTaskUIInterface.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils helpers.spec.res и helpers.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils\clientSchema Contact.res и Contact.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils\clientSchema ContactRole.res и ContactRole.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\contact\utils\next Contact.res и Contact.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\document\utils\clientSchema Document.res и Document.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\document\utils\clientSchema DocumentCategory.res и DocumentCategory.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\document\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\components\MarketplacePageContent ContextProvider.res и ContextProvider.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'refetchAcquiringContext': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\hooks useQueryTab.res и useQueryTab.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema Invoice.res и Invoice.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketCategory.res и MarketCategory.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketItem.res и MarketItem.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketItemFile.res и MarketItemFile.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketItemPrice.res и MarketItemPrice.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketPriceScope.res и MarketPriceScope.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema MarketSetting.res и MarketSetting.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\marketplace\utils\clientSchema search.res и search.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\components MetersDataImporterTypes.res и MetersDataImporterTypes.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'getMessages': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\hooks useMeterReadingExportTaskUIInterface.res и useMeterReadingExportTaskUIInterface.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\hooks useMeterValidations.res и useMeterValidations.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils helpers.res и helpers.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils helpers.spec.res и helpers.spec.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'COLD_WATER_METER_RESOURCE_ID': 1, 'HOT_WATER_METER_RESOURCE_ID': 1, 'GAS_SUPPLY_METER_RESOURCE_ID': 1, 'ELECTRICITY_METER_RESOURCE_ID': 1, 'HEAT_SUPPLY_METER_RESOURCE_ID': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema Meter.res и Meter.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterForOrganization.res и MeterForOrganization.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterReading.res и MeterReading.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterReadingFilterTemplate.res и MeterReadingFilterTemplate.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterReadingForOrganization.res и MeterReadingForOrganization.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterReadingSource.res и MeterReadingSource.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterReportingPeriod.res и MeterReportingPeriod.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterResource.res и MeterResource.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema MeterResourceOwner.res и MeterResourceOwner.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema PropertyMeter.res и PropertyMeter.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema PropertyMeterReading.res и PropertyMeterReading.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\meter\utils\clientSchema search.res и search.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\components\AppDescription index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\components\AppIndex index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\hooks useLaunchParams.res и useLaunchParams.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BApp.res и B2BApp.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppAccessRight.res и B2BAppAccessRight.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppAccessRightSet.res и B2BAppAccessRightSet.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppContext.res и B2BAppContext.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppNewsSharingConfig.res и B2BAppNewsSharingConfig.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppPermission.res и B2BAppPermission.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppPromoBlock.res и B2BAppPromoBlock.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2BAppRole.res и B2BAppRole.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2CApp.res и B2CApp.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2CAppAccessRight.res и B2CAppAccessRight.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2CAppBuild.res и B2CAppBuild.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema B2CAppProperty.res и B2CAppProperty.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\miniapp\utils\clientSchema MessageAppBlackList.res и MessageAppBlackList.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\components types.res и types.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useNewsItemRecipientsExportTaskUIInterface.res и useNewsItemRecipientsExportTaskUIInterface.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useNewsItemsAccess.res и useNewsItemsAccess.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\hooks useTableFilters.res и useTableFilters.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema NewsItem.res и NewsItem.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema NewsItemScope.res и NewsItemScope.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema NewsItemSharing.res и NewsItemSharing.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema NewsItemTemplate.res и NewsItemTemplate.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\news\utils\clientSchema NewsItemUserRead.res и NewsItemUserRead.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\notification\utils\clientSchema index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\notification\utils\clientSchema Message.res и Message.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\notification\utils\clientSchema MessageBatch.res и MessageBatch.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\condo\apps\condo\domains\notification\utils\clientSchema MessageOrganizationBlackList.res и MessageOrganizationBlackList.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ...
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out settings.d.res и settings.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\adapters fs.d.res и fs.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\providers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\providers common.d.res и common.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\providers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\types index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\utils fs.d.res и fs.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.scandir\out\utils index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out settings.d.res и settings.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out\adapters fs.d.res и fs.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out\providers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out\providers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.stat\out\types index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out settings.d.res и settings.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\providers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\providers index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\providers stream.d.res и stream.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\providers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\readers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\readers common.d.res и common.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\readers reader.d.res и reader.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\readers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@nodelib\fs.walk\out\types index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\body-parser index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\express-serve-static-core index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\node assert.d.res и assert.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\node module.d.res и module.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\node stream.d.res и stream.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\node test.d.res и test.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\@types\node vm.d.res и vm.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\apollo-server\dist exports.d.res и exports.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\apollo-server\dist index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\apollo-server\src exports.res и exports.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\apollo-server\src index.res и index.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
#   В .res есть, а в .res_land не хватает: {'constructor': 1, 'createServerInfo': 1, 'applyMiddleware': 1, 'start': 1, 'listen': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\array-union index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\call-bind-apply-helpers index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out settings.d.res и settings.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\managers tasks.d.res и tasks.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers provider.d.res и provider.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers stream.d.res и stream.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\filters deep.d.res и deep.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\filters entry.d.res и entry.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\filters error.d.res и error.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\matchers matcher.d.res и matcher.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\matchers partial.d.res и partial.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\providers\transformers entry.d.res и entry.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\readers async.d.res и async.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\readers reader.d.res и reader.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\readers stream.d.res и stream.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\readers sync.d.res и sync.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\types index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils array.d.res и array.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils errno.d.res и errno.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils fs.d.res и fs.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils path.d.res и path.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils pattern.d.res и pattern.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils stream.d.res и stream.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fast-glob\out\utils string.d.res и string.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fastq index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\fastq\test example.res и example.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\globby index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\ignore index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\path-type index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\queue-microtask index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# ❌ Разница в файлах e:\phd\ts_res\test\node_modules\slash index.d.res и index.d.res_land:
#   В .res_land есть, а в .res не хватает: {'ResolverTest_lambda_1_func_1': 1, 'ResolverTest_lambda_1_func_2': 1}
# OK: 0 (0.0%), BAD: 2813, TOTAL: 2813

# %%
87.59331674369001 349
# Out:
# 87.59331674369001

# %%
68.64
